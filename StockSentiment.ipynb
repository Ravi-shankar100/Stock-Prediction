# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravi-shankar100/Stock-Prediction/blob/master/StockSentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data.csv", encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#          Date  ...                         Top25
# 0  2000-01-03  ...            Recovering a title
# 1  2000-01-04  ...  Millennium bug fails to bite
# 2  2000-01-05  ...                  Useful links
# 3  2000-01-06  ...   Lessons of law's hard heart
# 4  2000-01-07  ...                    Gone aloft
#
# [5 rows x 27 columns]

# %%
train = df[df['Date'] < '20150101']
test = df[df['Date'] > '20141231']

# %%
train
# Out:
#             Date  ...                                              Top25
# 0     2000-01-03  ...                                 Recovering a title
# 1     2000-01-04  ...                       Millennium bug fails to bite
# 2     2000-01-05  ...                                       Useful links
# 3     2000-01-06  ...                        Lessons of law's hard heart
# 4     2000-01-07  ...                                         Gone aloft
# ...          ...  ...                                                ...
# 3970  2015-12-24  ...  Cameron, Osborne and Murdoch back together at ...
# 3971  2015-12-28  ...  Experiment in Germany tests the idea of an 'em...
# 3972  2015-12-29  ...  Israel warns Brazil to accept its settler amba...
# 3973  2015-12-30  ...  UK Sperm Bank Doesn't Accept Donors with Dysle...
# 3974  2015-12-31  ...  Hamas to keep Palestinians from ringing in New...
#
# [3975 rows x 27 columns]

# %%
test

# %%
#Removing the punctuations
data = train.iloc[: , 2:27]
data.replace(['^a-zA-Z'], ' ',regex = True, inplace = True)

# %%
#Renaming the columns indexes
list1 = [i for i in range(25)]
new_index = [str(i) for i in list1]
data.columns = new_index
data.head(5)

# %%
#Converting headlines to the lowercase
for index in new_index:
  data[index] = data[index].str.lower()
data.head(1)

# %%
headlines = []
row = 0
for row in range(row,len(data.index)):
  headlines.append(' '.join(str(x) for x in data.iloc[row,0:25]))

# %%
headlines[4]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
#Implement the Bag of Words Model
cv = CountVectorizer(ngram_range = (2,2))
traindataset = cv.fit_transform(headlines)

# %%
#Implementing the Random Forest Classifier
randomforest = RandomForestClassifier(n_estimators = 200, criterion= 'entropy')
randomforest.fit(traindataset , train['Label'])

# %%
#Predicting for the test data
test_transform = []
for row in range(0,len(test.index)):
  test_transform.append(' '.join(str(x) for x in test.iloc[row,2:27]))
test_dataset = cv.transform(test_transform)
predictions = randomforest.predict(test_dataset)

# %%
test_transform[1]

# %%
#Import Library to check Accuracy
from sklearn.metrics import classification_report , confusion_matrix, accuracy_score

# %%
cm = confusion_matrix(test['Label'] , predictions)
print(cm)
accuracy = accuracy_score(test['Label'],predictions)
print(accuracy)
report = classification_report(test['Label'], predictions)
print(report)
# Out:
# [[140  46]
#  [ 11 181]]
# 0.8492063492063492
#               precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83       186
#            1       0.80      0.94      0.86       192
#
#     accuracy                           0.85       378
#    macro avg       0.86      0.85      0.85       378
# weighted avg       0.86      0.85      0.85       378
